# %%
import csv
f = open('Iteration_Info_List.csv','r')
next(f) ## 첫째줄 건너뛰기
rdr = csv.reader(f)
vertex_zip = list()    

for vertex in rdr:
    vertex_zip.append([vertex[0], vertex[1], vertex[2]])
    print(vertex)
 
f.close()
# Out:
# ['1', '1166', '322.892']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/lk/9fdd4zc93ds0y2tm758kpqn40000gn/T/ipykernel_64577/2274280263.py in <module>
#       6
#       7 for vertex in rdr:
# ----> 8     vertex_zip.append([vertex[0], vertex[1], vertex[2]])
#       9     print(vertex)
#      10
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import csv
x=[]
y=[]   
f= open("Iteration_Info_List.csv")
next(f) ## 첫째줄 건너뛰기
#append values to list
for row in csv.reader(f):
    x.append(row[1])
    y.append(row[2])
    
fig,axes=plt.subplots(figsize=(16,5))
plt.grid(True)
plt.gca().invert_yaxis() # y축 순서 반대로 
#plt.gca().invert_xaxis() # x축 순서 반대로 

axes.tick_params(axis='x', labelsize=10)
axes.tick_params(axis='y', labelsize=10)
axes.xaxis.set_major_locator(ticker.MultipleLocator(10))
axes.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.xlabel('Iteration') 
plt.ylabel('Minimum value(Km)')


plt.plot(x, y)

plt.show()
